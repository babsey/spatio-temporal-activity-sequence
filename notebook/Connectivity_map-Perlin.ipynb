# %% [markdown]
# ## Perlin

# %% [markdown]
# Copyright 2019 Sebastian Spreizer
#
# The MIT License

# %%
import numpy as np
import pylab as pl

import project_path
import lib.connectivity_map as cm
import lib.colormap as cmap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-790c2ea9325d> in <module>()
#       3
#       4 import project_path
# ----> 5 import lib.connectivity_map as cm
#       6 import lib.colormap as cmap
#
# /home/spreizer/Projects/spatio-temporal-activity-sequence/notebook/lib/connectivity_map.py in <module>()
#       7
#       8 import numpy as np
# ----> 9 import noise
#      10
#      11
#
# ModuleNotFoundError: No module named 'noise'

# %%
nrow = 100
size = 4

# %%
landscape = cm.Perlin_uniform(nrow, size=size)
landscape *= 2 * np.pi

fig,ax = pl.subplots(1)
im = ax.matshow(landscape.reshape(nrow,nrow), cmap=cmap.virno(), origin='bottom')
cbar = pl.colorbar(im, ax=ax)
cbar.set_ticks([0,3.14,6.28])
cbar.set_ticklabels([0,'$\pi$','$2\pi$'])

# %%
azimuths = np.arange(0, 361)
zeniths = np.arange(1, 3)
values = azimuths * np.ones((2, 361))
fig, ax = pl.subplots(subplot_kw=dict(projection='polar'))
ax.pcolormesh(azimuths*np.pi/180.0, zeniths, values, cmap=cmap.virno())
ax.set_yticks([])
ax.set_xticks([0, np.pi/2, np.pi, np.pi*3/2])
ax.set_xticklabels(['0', '$\pi/2$', '$\pi$', '$3/2\pi$'])
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '$\\pi/2$'),
#  Text(0, 0, '$\\pi$'),
#  Text(0, 0, '$3/2\\pi$')]
